# %%
import pandas as pd

# Create a dictionary with 5 columns
data = {
    "Name": [
        "Abel", "Sara", "John", "Mina", "David",
        "Liya", "Noah", "Ruth", "Eden", "Samuel",
        "Hana", "Daniel", "Betty", "Kaleb", "Rahel"
    ],
    "Age": [
        23, 21, 25, 22, 24,
        20, 26, 23, 22, 27,
        21, 28, 24, 23, 22
    ],
    "Gender": [
        "M", "F", "M", "F", "M",
        "F", "M", "F", "F", "M",
        "F", "M", "F", "M", "F"
    ],
    "Score": [
        85, 90, 78, 88, 92,
        76, 81, 89, 84, 95,
        87, 93, 80, 82, 86
    ],
    "City": [
        "Adama", "Addis Ababa", "Hawassa", "Bahir Dar", "Dire Dawa",
        "Mekele", "Addis Ababa", "Hawassa", "Gonder", "Metu",
        "Adama", "Addis Ababa", "Debre Birhan", "Bahir Dar", "Jima"
    ]
}


custom_index = [f"ID_{i}" for i in range(1, 16)]

df = pd.DataFrame(data, index=custom_index)

print(df)
# Out:
#          Name  Age Gender  Score          City
# ID_1     Abel   23      M     85         Adama
# ID_2     Sara   21      F     90   Addis Ababa
# ID_3     John   25      M     78       Hawassa
# ID_4     Mina   22      F     88     Bahir Dar
# ID_5    David   24      M     92     Dire Dawa
# ID_6     Liya   20      F     76        Mekele
# ID_7     Noah   26      M     81   Addis Ababa
# ID_8     Ruth   23      F     89       Hawassa
# ID_9     Eden   22      F     84        Gonder
# ID_10  Samuel   27      M     95          Metu
# ID_11    Hana   21      F     87         Adama
# ID_12  Daniel   28      M     93   Addis Ababa
# ID_13   Betty   24      F     80  Debre Birhan
# ID_14   Kaleb   23      M     82     Bahir Dar
# ID_15   Rahel   22      F     86          Jima
